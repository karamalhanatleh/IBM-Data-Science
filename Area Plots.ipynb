# %% [markdown]
# # Area Plots

# %%
#import 
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read data
df_can = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2)

df_can
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1       Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2       Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3             Polynesia  902  Developing regions     0  ...     0     0     1
# 4       Southern Europe  901   Developed regions     0  ...     0     0     1
# ..                  ...  ...                 ...   ...  ...   ...   ...   ...
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 0    2652  2111  1746  1758  2203  2635  2004
# 1     702   560   716   561   539   620   603
# 2    3623  4005  5393  4752  4325  3774  4331
# 3       0     0     0     0     0     0     0
# 4       1     0     0     0     0     1     1
# ..    ...   ...   ...   ...   ...   ...   ...
# 190  2574  1784  2171  1942  1723  1731  2112
# 191     0     0     0     0     0     0     0
# 192   122   133   128   211   160   174   217
# 193    71    64    60   102    69    46    59
# 194   663   611   508   494   434   437   407
#
# [195 rows x 43 columns]

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([     'Type',  'Coverage',   'Country',      'AREA', 'Continent',
#              'REG',    'Region',       'DEV',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can['Total'] = df_can.sum(axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18556\552165185.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_can['Total'] = df_can.sum(axis=1)

# %%
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# %%
df_can.sort_values(['Total'] , ascending=False , axis= 0 , inplace=True)

# %%
df_can
# Out:
#                                                            Continent  \
# Country
# India                                                           Asia
# China                                                           Asia
# United Kingdom of Great Britain and Northern Ir...            Europe
# Philippines                                                     Asia
# Pakistan                                                        Asia
# ...                                                              ...
# New Caledonia                                                Oceania
# San Marino                                                    Europe
# Canada                                              Northern America
# Sao Tome and Principe                                         Africa
# Western Sahara                                                Africa
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
# ...                                                                ...
# New Caledonia                                                Melanesia
# San Marino                                             Southern Europe
# Canada                                                Northern America
# Sao Tome and Principe                                    Middle Africa
# Western Sahara                                         Northern Africa
#
#                                                                DevName   1980  \
# Country
# India                                               Developing regions   8880
# China                                               Developing regions   5123
# United Kingdom of Great Britain and Northern Ir...   Developed regions  22045
# Philippines                                         Developing regions   6051
# Pakistan                                            Developing regions    978
# ...                                                                ...    ...
# New Caledonia                                       Developing regions      0
# San Marino                                           Developed regions      1
# Canada                                               Developed regions      0
# Sao Tome and Principe                               Developing regions      0
# Western Sahara                                      Developing regions      0
#
#                                                      1981   1982   1983  \
# Country
# India                                                8670   8147   7338
# China                                                6682   3308   1863
# United Kingdom of Great Britain and Northern Ir...  24796  20620  10015
# Philippines                                          5921   5249   4562
# Pakistan                                              972   1201    900
# ...                                                   ...    ...    ...
# New Caledonia                                           0      0      0
# San Marino                                              0      0      0
# Canada                                                  0      0      0
# Sao Tome and Principe                                   0      0      0
# Western Sahara                                          0      0      0
#
#                                                      1984  1985  1986  ...  \
# Country                                                                ...
# India                                                5704  4211  7150  ...
# China                                                1527  1816  1960  ...
# United Kingdom of Great Britain and Northern Ir...  10170  9564  9470  ...
# Philippines                                          3801  3150  4166  ...
# Pakistan                                              668   514   691  ...
# ...                                                   ...   ...   ...  ...
# New Caledonia                                           0     0     0  ...
# San Marino                                              0     0     1  ...
# Canada                                                  0     0     0  ...
# Sao Tome and Principe                                   0     0     0  ...
# Western Sahara                                          0     0     0  ...
#
#                                                      2005   2006   2007  \
# Country
# India                                               36210  33848  28742
# China                                               42584  33518  27642
# United Kingdom of Great Britain and Northern Ir...   7258   7140   8216
# Philippines                                         18139  18400  19837
# Pakistan                                            14314  13127  10124
# ...                                                   ...    ...    ...
# New Caledonia                                           0      0      0
# San Marino                                              0      0      0
# Canada                                                  0      0      0
# Sao Tome and Principe                                   1      1      0
# Western Sahara                                          0      1      0
#
#                                                      2008   2009   2010  \
# Country
# India                                               28261  29456  34235
# China                                               30037  29622  30391
# United Kingdom of Great Britain and Northern Ir...   8979   8876   8724
# Philippines                                         24887  28573  38617
# Pakistan                                             8994   7217   6811
# ...                                                   ...    ...    ...
# New Caledonia                                           1      0      0
# San Marino                                              0      0      1
# Canada                                                  0      0      0
# Sao Tome and Principe                                   0      1      2
# Western Sahara                                          0      0      0
#
#                                                      2011   2012   2013  \
# Country
# India                                               27509  30933  33087
# China                                               28502  33024  34129
# United Kingdom of Great Britain and Northern Ir...   6204   6195   5827
# Philippines                                         36765  34315  29544
# Pakistan                                             7468  11227  12603
# ...                                                   ...    ...    ...
# New Caledonia                                           0      0      2
# San Marino                                              0      0      0
# Canada                                                  1      1      2
# Sao Tome and Principe                                   0      0      1
# Western Sahara                                          0      0      0
#
#                                                      Total
# Country
# India                                               699242
# China                                               662705
# United Kingdom of Great Britain and Northern Ir...  554233
# Philippines                                         514148
# Pakistan                                            248938
# ...                                                    ...
# New Caledonia                                         2744
# San Marino                                            2739
# Canada                                                2731
# Sao Tome and Principe                                 2726
# Western Sahara                                        2719
#
# [195 rows x 38 columns]

# %%
df_can.loc['Jordan']
# Out:
# Continent                  Asia
# Region             Western Asia
# DevName      Developing regions
# 1980                        177
# 1981                        160
# 1982                        155
# 1983                        113
# 1984                        102
# 1985                        179
# 1986                        181
# 1987                        392
# 1988                        489
# 1989                        785
# 1990                        841
# 1991                        807
# 1992                        909
# 1993                       1141
# 1994                       1173
# 1995                       1006
# 1996                       1070
# 1997                       1317
# 1998                        999
# 1999                       1218
# 2000                       1511
# 2001                       1904
# 2002                       1499
# 2003                       1614
# 2004                       1733
# 2005                       1940
# 2006                       1827
# 2007                       1421
# 2008                       1581
# 2009                       1235
# 2010                       1831
# 2011                       1635
# 2012                       1206
# 2013                       1255
# Total                     38165
# Name: Jordan, dtype: object

# %% [markdown]
# ### Generate Area Plots

# %%
years = list(map(str , range(1980 , 2014)))
df_can.sort_values(['Total'] , ascending=False , axis = 0 , inplace=True)

df_top5 = df_can.head()
df_top5
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# India                                               Developing regions   8880
# China                                               Developing regions   5123
# United Kingdom of Great Britain and Northern Ir...   Developed regions  22045
# Philippines                                         Developing regions   6051
# Pakistan                                            Developing regions    978
#
#                                                      1981   1982   1983  \
# Country
# India                                                8670   8147   7338
# China                                                6682   3308   1863
# United Kingdom of Great Britain and Northern Ir...  24796  20620  10015
# Philippines                                          5921   5249   4562
# Pakistan                                              972   1201    900
#
#                                                      1984  1985  1986  ...  \
# Country                                                                ...
# India                                                5704  4211  7150  ...
# China                                                1527  1816  1960  ...
# United Kingdom of Great Britain and Northern Ir...  10170  9564  9470  ...
# Philippines                                          3801  3150  4166  ...
# Pakistan                                              668   514   691  ...
#
#                                                      2005   2006   2007  \
# Country
# India                                               36210  33848  28742
# China                                               42584  33518  27642
# United Kingdom of Great Britain and Northern Ir...   7258   7140   8216
# Philippines                                         18139  18400  19837
# Pakistan                                            14314  13127  10124
#
#                                                      2008   2009   2010  \
# Country
# India                                               28261  29456  34235
# China                                               30037  29622  30391
# United Kingdom of Great Britain and Northern Ir...   8979   8876   8724
# Philippines                                         24887  28573  38617
# Pakistan                                             8994   7217   6811
#
#                                                      2011   2012   2013  \
# Country
# India                                               27509  30933  33087
# China                                               28502  33024  34129
# United Kingdom of Great Britain and Northern Ir...   6204   6195   5827
# Philippines                                         36765  34315  29544
# Pakistan                                             7468  11227  12603
#
#                                                      Total
# Country
# India                                               699242
# China                                               662705
# United Kingdom of Great Britain and Northern Ir...  554233
# Philippines                                         514148
# Pakistan                                            248938
#
# [5 rows x 38 columns]

# %%
df_can.index = df_can.index.map(int) # let's change the index values of df_CI to type integer for plotting
df_can.plot(kind='line')

plt.title('Immigrants from China and India')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18556\581556962.py in <module>
# ----> 1 df_can.index = df_can.index.map(int) # let's change the index values of df_CI to type integer for plotting
#       2 df_can.plot(kind='line')
#       3
#       4 plt.title('Immigrants from China and India')
#       5 plt.ylabel('Number of Immigrants')
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in map(self, mapper, na_action)
#    6088         from pandas.core.indexes.multi import MultiIndex
#    6089
# -> 6090         new_values = self._map_values(mapper, na_action=na_action)
#    6091
#    6092         # we can return a MultiIndex
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     878
#     879         # mapper is a function
# --> 880         new_values = map_f(values, mapper)
#     881
#     882         return new_values
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: invalid literal for int() with base 10: 'India'
