# %% [markdown]
# # Introduction to Matplotlib

# %%
#import packages

import numpy as np

import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas #import FigureCanvas
from matplotlib.figure import Figure # import Figure artist

# %%
fig=Figure()
canvas=FigureCanvas(fig)

# %%
#generate 1000 random number 
x=np.random.randn(10000)

# %%
ax= fig.add_subplot(111) #create an axes artist
ax.hist(x,100)  # generate a histogram of the 1000 number 
#add a title to the figure and save it
ax.set_title("Normal distribution with $\mu=0 , \sigma=1$")
fig.savefig("matplotlin_hist.png")

# %%
x=np.random.randn(10000)
plt.hist(x, 100)
plt.title(r'Normal disterbution with $\mu=0 , \sigma=1$')
plt.savefig("matplotlib_hist.png")
plt.show()
